# %% [markdown]
# Introduction: Introduce the project, and your approach, talk about the process of how you came up with the metric and some alternatives you may have explored.
#
# Our project focuses on evaluating datasets to determine which neighborhood can be considered the “best” based on measurable, data‑driven criteria. Because “best” is subjective, our first step was to identify which qualities matter most to residents and how those qualities could be quantified in a meaningful way. Our submetrics are eco-friendliness, safety, cleanliness and toxicity levels. We also explored affordability, walkability, property-level quality, and school quality but decided our final choices were the best. Our submetrics are accurate measurements of what the best neighborhood is because our selection is diverse and covers a lot of areas. All these factors contribute to the quality of life in a neighborhood which is important when considering which one is the best.
#
# The Metric: Describe your metric, and what features are you measuring. What datasets are you using?
#
# Our metric evaluates neighborhoods across four main features:
# 1. Eco‑Friendliness
# Measured using the Operations – Green Spaces dataset from the Western Pennsylvania Regional Data Center. We analyzed:
# - Total acreage of green spaces
# - Maintainable acreage
# - Number and distribution of green‑space facilities
# This allowed us to quantify how much natural space each neighborhood offers.
# 2. Safety
# Measured using crime‑related datasets (e.g., incident reports). We aggregated incidents by neighborhood to estimate relative safety levels.
# 3. Cleanliness
# Measured using datasets related to public works, maintenance, or 311 cleanliness‑related requests. This helped us approximate how well‑maintained each neighborhood is.
# 4. Toxicity Levels
# Measured using the Toxic Release Inventory dataset. We filtered by ZIP code, and summed total toxic releases to determine which neighborhoods experience the least environmental pollution in terms of toxicity.
# Each submetric was normalized and compared across neighborhoods to identify which area consistently performed well across categories.
#
# The Best Neighborhood: Apply the metric from the previous section to determine the best neighborhood in Pittsburgh. Beyond just executing code, provide a narrative about why you think this is the best neighborhood. Incorporate a data visualization, perhaps to rank all of the neighborhoods or show a neighborhood’s best-ness over time. The key is to make a data driven argument.
#
# After applying our metric, East Liberty emerged as the best neighborhood overall. The data consistently showed that East Liberty performs strongly across multiple categories. In addition, East Liberty performed well in our toxicity analysis. While some neighborhoods had extremely high toxic release totals, East Liberty’s values were comparatively moderate, placing it in a safer environmental range than industrial‑heavy areas like Lawrenceville. When we combined eco‑friendliness, safety, cleanliness, and toxicity levels, East Liberty consistently ranked near the top. The neighborhood’s strong environmental profile, paired with relatively low pollution and solid performance in other categories, made it the most balanced and high‑scoring neighborhood in our metric.
#
# Conclusion: Reflect on how the data-driven determination of “best neighborhood” is the same or different from your personal favorite neighborhood. Each member of the group should write their own response to this.
#
# Jacqueline: Our data‑driven analysis identified East Liberty as the best neighborhood based on our selected submetrics. However, personal preferences don’t always align with data. My personal favorite neighborhood is Shadyside, and the reasons behind that choice are very different from the criteria used in our metric. I like Shadyside for its walkability, local shops, tree‑lined streets, and overall atmosphere. This contrast highlights an important point: data can tell us which neighborhood performs best on measurable factors, but personal experience shapes what “best” means to each individual.
#
# Eman: East Liberty had 8,451 crime incidents, which was lower than Central Business District, South Side Flats, and Carrick in my comparison. This suggests that East Liberty performed well in terms of safety among the neighborhoods I selected. Although some Pittsburgh neighborhoods may have lower totals overall, East Liberty compared favorably against several popular areas. Overall, East Liberty appears to be a relatively safe neighborhood based on this analysis.
#
# Gabrielle: Shadyside is objectively the best neighborhood in Pittsburgh. It ranks #1 out of 79 neighborhoods, sits 11% ahead of East Liberty (the runner-up), and scores 5x above the citywide mean. Its investment is consistent year-over-year and reflects the surrounding environment. Shadyside was one of the first Pittsburgh neighborhoods I visited as a Pitt student, and it makes sense why it's so far ahead of its competitors. There are so many housing developments, stores, including large box stores like Target, and a wealth of restaurants and other smaller businesses. It's accessible to students in Oakland, urban citizens downtown who don't have easy access to grocery stores nearby, and tourists.
#
# As Pittsburgh grows in popularity again, Shaydside is feeling much of the pressure. Consistently adding more smart trash receptacles is one way they're meeting consumer demand, and it is indicative of a larger investment in the community.
#
# Vibha: Using data from the Western Pennsylvania Regional Data Center (WPRDC), I analyzed total toxic air releases as a key indicator of environmental risk. Neighborhoods with lower levels of toxic emissions are considered more
# favorable, as they suggest cleaner air and reduced health risks. This metric is both quantifiable and comparable,
# allowing for a clear, data-driven evaluation of environmental quality across neighborhoods.This led me to focus on a more concrete and impactful factor: environmental safety. Specifically, I examined air quality by analyzing
# toxic chemical releases into the air. making it a critical and measurable component of neighborhood livability.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("greenspaces.csv")
df = df[['Neighborhood', "Total Acreage", "Maintainable Acreage"]]

df['Total Acreage'] = pd.to_numeric(df['Total Acreage'], errors='coerce')
df['Maintainable Acreage'] = pd.to_numeric(df['Maintainable Acreage'], errors='coerce')


df = df.dropna(subset=['Neighborhood'])


metric = 'Total Acreage'   


grouped = df.groupby('Neighborhood')[metric].sum().sort_values()

print(grouped)
print("\nNeighborhood with the lowest total acreage:", grouped.idxmin())

# Plot
plt.figure(figsize=(12,6))
grouped.plot(kind='bar')
plt.title(f"Total {metric} by Neighborhood")
plt.xlabel("Neighborhood")
plt.ylabel(metric)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Neighborhood
# Regent Square                0.01
# Polish Hill                  0.01
# Swisshelm Park               0.05
# Beechview                    0.10
# Sheraden                     0.10
# Brookline                    0.10
# North Oakland                0.10
# Crawford Roberts             0.30
# South Oakland                0.30
# Squirrel Hill South          0.40
# Point Breeze                 1.12
# Central Business District    1.24
# Point Breeze North           1.40
# Central Oakland              1.70
# East Liberty                 4.15
# Name: Total Acreage, dtype: float64
#
# Neighborhood with the lowest total acreage: Regent Square

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("saftey.csv")
df.head()
crime_by_neighborhood = df["Neighborhood"].value_counts()

selected = crime_by_neighborhood[
    ["East Liberty", "Central Business District", "South Side Flats", "Carrick"]
]
selected.plot(kind="bar", figsize=(8,5))
plt.title("Safety Comparison Between Selected Neighborhoods")
plt.xlabel("Neighborhood")
plt.ylabel("Crime Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np

# load the dataset
df = pd.read_csv('smarttrash.csv')

# parse dates
df['assignment_date'] = pd.to_datetime(df['assignment_date'])
df['last_updated_date'] = pd.to_datetime(df['last_updated_date'])
df['year'] = df['assignment_date'].dt.year

# drop rows with missing neighborhood
df = df.dropna(subset=['neighborhood'])

print(f"Dataset shape: {df.shape}")
print(f"Neighborhoods represented: {df['neighborhood'].nunique()}")
print(f"Date range: {df['assignment_date'].min().date()} to {df['assignment_date'].max().date()}")
df.head()# total smart containers per neighborhood
scores = df['neighborhood'].value_counts().reset_index()
scores.columns = ['neighborhood', 'smart_trash']

print("Top 15 Neighborhoods by Smart Trash Cans:")
print(scores.head(15).to_string(index=False))
top20 = scores.head(20).copy()
colors = ['#86659C' if n == 'Shadyside' else '#B48FCC' for n in top20['neighborhood']]

fig, ax = plt.subplots(figsize=(12, 7))
ax.barh(top20['neighborhood'][::-1], top20['smart_trash'][::-1], color=colors[::-1])

for bar in ax.patches:
    ax.text(bar.get_width() + 0.5, bar.get_y() + bar.get_height() / 2,
            int(bar.get_width()), va='center', ha='left', fontsize=9)

ax.set_title('Pittsburgh Smart Trash Receptacles per Neighborhood', fontweight='bold', pad=12)
ax.set_xlim(0, 90)
ax.axis('off')

plt.tight_layout()
plt.savefig('neighborhood_rankings.png', dpi=150, bbox_inches='tight')
plt.show()
total_neighborhoods = df['neighborhood'].nunique()
shadyside_score = scores[scores['neighborhood'] == 'Shadyside']['smart_trash'].values[0]
second_place = scores.iloc[1]

print(f"Total neighborhoods analyzed:  {total_neighborhoods}")
print(f"\n#1  Shadyside:                  {shadyside_score} receptacles")
print(f"#2  {second_place['neighborhood']}:             {second_place['smart_trash']} receptacles")
# Out:
# Dataset shape: (1193, 18)
# Neighborhoods represented: 79
# Date range: 2017-09-14 to 2022-03-09
# Top 15 Neighborhoods by Smart Trash Cans:
#          neighborhood  smart_trash
#             Shadyside           76
#          East Liberty           68
#   Squirrel Hill South           63
#            Bloomfield           58
#           North Shore           53
#      South Side Flats           51
#        Strip District           42
#               Carrick           38
#       Central Oakland           34
# Central Lawrenceville           29
#           Middle Hill           29
#   Lower Lawrenceville           29
#                 Bluff           28
#        Homewood South           28
#        East Allegheny           26
# Total neighborhoods analyzed:  79
#
# #1  Shadyside:                  76 receptacles
# #2  East Liberty:             68 receptacles

# %%
import pandas as pd
import matplotlib.pyplot as plt


url = "https://data.wprdc.org/datastore/dump/2750b8c8-246b-430f-b1e0-1aa96e00b013"
df = pd.read_csv(url)

df = df[['ZIP_CODE', 'TOTAL_RELEASE']]


df['TOTAL_RELEASE'] = pd.to_numeric(df['TOTAL_RELEASE'], errors='coerce')
df = df.dropna()
df['ZIP_CODE'] = df['ZIP_CODE'].astype(str)


zip_to_neighborhood = {"15206": "East Liberty", "15201": "Lawrenceville", "15213": "Oakland", "15144": "Springdale",
"15104": "Braddock"}
df['neighborhood'] = df['ZIP_CODE'].map(zip_to_neighborhood)


df = df.dropna(subset=['neighborhood'])

grouped = df.groupby('neighborhood')['TOTAL_RELEASE'].sum()
grouped = grouped.sort_values()

print(grouped)
print("\nCleanest neighborhood (lowest total release):", grouped.idxmin())


grouped.plot(kind='bar')
plt.title("Total Toxic Release by Neighborhood")
plt.xlabel("Neighborhood")
plt.ylabel("Total Toxic Release")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# neighborhood
# East Liberty     4.689850e+05
# Lawrenceville    1.120824e+06
# Braddock         3.263562e+06
# Springdale       4.241751e+07
# Name: TOTAL_RELEASE, dtype: float64
#
# Cleanest neighborhood (lowest total release): East Liberty
